# %%
sobelx= cv2.Sobel(img,cv2.CV_64F , 1,0,5)
sobely= cv2.Sobel(img,cv2.CV_64F , 0,1,5)

#lapiacian(img,ddepath)
laplacian_img = cv2.Laplacian(img, cv2.CV_64F)

#canny
canny_img = cv2.Canny(img, 50 , 150 )

plt.figure(figsize=(15, 15))

plt.subplot(1,5,1),plt.imshow(img , cmap="gray")
plt.axis('off')
plt.subplot(1,5,2),plt.imshow(sobelx, cmap="gray")
plt.axis('off')
plt.subplot(1,5,3),plt.imshow(sobely, cmap="gray")
plt.axis('off')

plt.subplot(1,5,4),plt.imshow(laplacian_img, cmap="gray")
plt.axis('off')

plt.subplot(1,5,5),plt.imshow(canny_img, cmap="gray")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_92/101927772.py in <module>
# ----> 1 sobelx= cv2.Sobel(img,cv2.CV_64F , 1,0,5)
#       2 sobely= cv2.Sobel(img,cv2.CV_64F , 0,1,5)
#       3
#       4 #lapiacian(img,ddepath)
#       5 laplacian_img = cv2.Laplacian(img, cv2.CV_64F)
#
# NameError: name 'cv2' is not defined

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img= cv2.imread("img.jfif")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
sobelx= cv2.Sobel(img,cv2.CV_64F , 1,0,5)
sobely= cv2.Sobel(img,cv2.CV_64F , 0,1,5)

#lapiacian(img,ddepath)
laplacian_img = cv2.Laplacian(img, cv2.CV_64F)

#canny
canny_img = cv2.Canny(img, 50 , 150 )

plt.figure(figsize=(15, 15))

plt.subplot(1,5,1),plt.imshow(img , cmap="gray")
plt.axis('off')
plt.subplot(1,5,2),plt.imshow(sobelx, cmap="gray")
plt.axis('off')
plt.subplot(1,5,3),plt.imshow(sobely, cmap="gray")
plt.axis('off')

plt.subplot(1,5,4),plt.imshow(laplacian_img, cmap="gray")
plt.axis('off')

plt.subplot(1,5,5),plt.imshow(canny_img, cmap="gray")
plt.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 249.5, 147.5, -0.5)

# %%
img=cv2.imread("img.jfif")
k1=np.ones((5,5))
erode_img=cv2.erode(img,k1,iterations=2)
dialte_img=cv2.dilate(img,k1,iterations=2)

plt.subplot(1,3,1),plt.imshow(img),plt.title("orignal")
plt.subplot(1,3,2),plt.imshow(erode_img),plt.title("erode")
plt.subplot(1,3,3),plt.imshow(dialte_img),plt.title("dialte")
# Out:
# (<AxesSubplot:title={'center':'dialte'}>,
#  <matplotlib.image.AxesImage at 0x16163243e50>,
#  Text(0.5, 1.0, 'dialte'))

# %%
img=cv2.imread("img5.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_YUV=cv2.cvtColor(img,cv2.COLOR_RGB2YUV)
img_YUV[:,:,1]=cv2.equalizeHist(img_YUV[:,:,1])
final_img=cv2.cvtColor(img_YUV,cv2.COLOR_YUV2BGR)

plt.subplot(1,2,1),plt.imshow(img)
plt.subplot(1,2,2),plt.imshow(final_img)
plt.tight_layout()
